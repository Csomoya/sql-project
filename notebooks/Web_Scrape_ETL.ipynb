# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
#Had to make a function in order to go through the pages
def scrape_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    #empty dictionary
    cve_data = {
        "cve": [],
        "desc": [],
        "vendor_prod": [],
        "Ransomware": [],
        "Due Date": [],
        "Action": []
    }
    
    for article in soup.find_all("article", class_="c-teaser c-teaser--horizontal"):
        
        #CVE data
        cve_id = article.find("h3", class_="c-teaser__title").text.strip()
        cve_data['cve'].append(cve_id)
        
        #Description data
        description = article.find("div", class_="c-teaser__vuln-name").text.strip()
        cve_data['desc'].append(description)
        
        #Vendor Product Data
        vendor_product = article.find("div", class_="c-teaser__eyebrow").text.strip()
        cve_data['vendor_prod'].append(vendor_product)
        
        #Ransom
        action_elem = article.find("span", class_="c-teaser__kev-label", text="Action:")
        ransom = action_elem.find_next("li").text.strip() if action_elem and action_elem.find_next("li") else "Action not specified"
        cve_data['Ransomware'].append(ransom)
        
        #I didn't use this part
        ransomware_campaign_elem = article.find("span", class_="c-teaser__kev-label", text="Known To Be Used in Ransomware Campaigns?:")
        ransomware_campaign = ransomware_campaign_elem.find_next("li").text.strip() if ransomware_campaign_elem and ransomware_campaign_elem.find_next("li") else np.NaN
        
        #Due Date Data
        date_added_elem = article.find("span", class_="c-teaser__kev-label", text="Date Added:")
        due_date = date_added_elem.find_next("li").text.strip() if date_added_elem and date_added_elem.find_next("li") else "Date not specified"
        cve_data['Due Date'].append(due_date)
        
        #Action Data
        due_date_elem = article.find("span", class_="c-teaser__kev-label", text="Due Date:")
        action = due_date_elem.find_next("li").text.strip() if due_date_elem and due_date_elem.find_next("li") else "Due date not specified"
        cve_data['Action'].append(action)
        
        
    return cve_data

#Function to help collect data from the first five pages
def scrape_vulnerability_data():
    url = "https://www.cisa.gov/known-exploited-vulnerabilities-catalog"
    all_cve_data = {
        "cve": [],
        "desc": [],
        "vendor_prod": [],
        "Ransomware": [],
        "Due Date": [],
        "Action": []
    }
    
    for page_num in range(1, 6):
        page_url = f"{url}?page={page_num}"
        cve_data = scrape_page(page_url)
        for key in all_cve_data:
            all_cve_data[key].extend(cve_data[key])
    
    return all_cve_data


cve_data = scrape_vulnerability_data()

# %%
#Making Dataframe
df = pd.DataFrame(cve_data)
df
# Out:
#                cve                                               desc  \
# 0    CVE-2024-1709  ConnectWise ScreenConnect Authentication Bypas...
# 1   CVE-2024-21410  Microsoft Exchange Server Privilege Escalation...
# 2    CVE-2020-3259  Cisco ASA and FTD Information Disclosure Vulne...
# 3   CVE-2024-21351  Microsoft Windows SmartScreen Security Feature...
# 4   CVE-2024-21412  Microsoft Windows Internet Shortcut Files Secu...
# ..             ...                                                ...
# 95  CVE-2023-38831         RARLAB WinRAR Code Execution Vulnerability
# 96  CVE-2023-32315  Ignite Realtime Openfire Path Traversal Vulner...
# 97  CVE-2023-38035  Ivanti Sentry Authentication Bypass Vulnerability
# 98  CVE-2023-27532  Veeam Backup & Replication Cloud Connect Missi...
# 99  CVE-2023-26359  Adobe ColdFusion Deserialization of Untrusted ...
#
#                                           vendor_prod  \
# 0                         ConnectWise | ScreenConnect
# 1                         Microsoft | Exchange Server
# 2   Cisco | Adaptive Security Appliance (ASA) and ...
# 3                                 Microsoft | Windows
# 4                                 Microsoft | Windows
# ..                                                ...
# 95                                    RARLAB | WinRAR
# 96                         Ignite Realtime | Openfire
# 97                                    Ivanti | Sentry
# 98                       Veeam | Backup & Replication
# 99                                 Adobe | ColdFusion
#
#                                            Ransomware              Due Date  \
# 0   Known To Be Used in Ransomware Campaigns?:  Known  Due Date: 2024-02-29
# 1   Known To Be Used in Ransomware Campaigns?:  Un...  Due Date: 2024-03-07
# 2   Known To Be Used in Ransomware Campaigns?:  Known  Due Date: 2024-03-07
# 3   Known To Be Used in Ransomware Campaigns?:  Un...  Due Date: 2024-03-05
# 4   Known To Be Used in Ransomware Campaigns?:  Un...  Due Date: 2024-03-05
# ..                                                ...                   ...
# 95  Known To Be Used in Ransomware Campaigns?:  Known  Due Date: 2023-09-14
# 96  Known To Be Used in Ransomware Campaigns?:  Un...  Due Date: 2023-09-14
# 97  Known To Be Used in Ransomware Campaigns?:  Un...  Due Date: 2023-09-12
# 98  Known To Be Used in Ransomware Campaigns?:  Known  Due Date: 2023-09-12
# 99  Known To Be Used in Ransomware Campaigns?:  Un...  Due Date: 2023-09-11
#
#                                                Action
# 0   Action: Apply mitigations per vendor instructi...
# 1   Action: Apply mitigations per vendor instructi...
# 2   Action: Apply mitigations per vendor instructi...
# 3   Action: Apply mitigations per vendor instructi...
# 4   Action: Apply mitigations per vendor instructi...
# ..                                                ...
# 95  Action: Apply mitigations per vendor instructi...
# 96  Action: Apply mitigations per vendor instructi...
# 97  Action: Apply mitigations per vendor instructi...
# 98  Action: Apply mitigations per vendor instructi...
# 99                              Go to first pageFirst
#
# [100 rows x 6 columns]

# %%
#Dataframe to CSV
df.to_csv('cve_data.csv', index = False)
